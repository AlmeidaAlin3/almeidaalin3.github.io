# %% [markdown]
# ---
# title: "Mech Interp Experiment"
# toc: true
# toc-depth: 4
# ---

# %% [markdown]
# # Hello World! :)

# %%
5+5
# Out:
# 10

# %% [markdown]
# ## Ola que tal?

# %%
10+1
# Out:
# 11

# %% [markdown]
# ### Bien e tu que tal?

# %% [markdown]
# ### muy bien gracias!
